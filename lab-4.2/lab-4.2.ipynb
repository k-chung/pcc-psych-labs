# %%
# Run this cell, but please don't change it.

# These lines import the Numpy and Datascience modules.
import numpy as np
from datascience import *

# These lines do some fancy plotting magic:
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# <font color="brown" size="5">1. Correlation and Regression 📈</font>
#
# We are interested in see if there is a relationship between student’s quiz score and course grade.
#
# The question we are trying to answer is: Is quiz score a good predictor of course grade?

# %% [markdown]
# **Question 1.1:** In the `show()` function, enter the number of rows you'd like to show. It could be 1, 5, 7, etc. Also see what happens if you don't specify a number of rows!

# %%
# Read in the data:
quiz_tbl = Table().read_table("Quiz Score and Course Grade.csv")
quiz_tbl.show(...)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Student</th> <th>Quiz Score</th> <th>Course Grade</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1      </td> <td>95        </td> <td>85.34       </td>
#         </tr>
#         <tr>
#             <td>2      </td> <td>100       </td> <td>88.24       </td>
#         </tr>
#         <tr>
#             <td>3      </td> <td>60        </td> <td>53.57       </td>
#         </tr>
#         <tr>
#             <td>4      </td> <td>95        </td> <td>83.26       </td>
#         </tr>
#         <tr>
#             <td>5      </td> <td>100       </td> <td>98.01       </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (27 rows omitted)</p>

# %% [markdown]
# **Question 1.2:** Create a scatter plot with Quiz Score on the x-axis and Course Grade on the y-axis. Make sure to enter the names exactly as they appear in the table above, which you just displayed. Quiz score should go first, then course grade.

# %%
# use the simple .scatter() method from datascience
quiz_tbl.scatter('...', '...')

# %% [markdown]
# <font color="brown" size="5">2. Generate the correlation matrix output 𝄜</font>

# %% [markdown]
# **Question 2.1:** Define 2 variables: `quiz_scores` and `course_grades`. What should go into the ellipses?

# %%
# Get the data columns as arrays
quiz_scores = quiz_tbl.column('...')
course_grades = quiz_tbl.column('...')

print("quiz scores:", quiz_scores)
print("course grades:", course_grades)
# Out:
# quiz scores: [ 95 100  60  95 100  80  85 100 100  95 100  85  90  90  85 100  25  90
#   95 100  40  55  80  85  80  90  90  85  90  90  40  85]
# course grades: [ 85.34  88.24  53.57  83.26  98.01  45.08  47.88  84.24  99.15  79.49
#   91.99  70.47  90.38  74.79  56.1   99.79  49.11  56.95  88.77  99.62
#   84.79  53.31  57.08  72.33  67.46  85.21  90.38  76.26  66.14  47.46
#   85.33  45.38]

# %% [markdown]
# **Question 2.2:** Using the variables you just defined, use them in `np.corrcoef` to get the correlation matrix.

# %%
corr_matrix = np.corrcoef(..., ...)

print(corr_matrix)
# Out:
# [[ 1.          0.41351821]
#  [ 0.41351821  1.        ]]

# %% [markdown]
# <font color="brown" size="5">3. Regression Line 📈</font>

# %% [markdown]
# **Question 3.0:**  Using previous variables, get the correlation coefficient (r) and the Correlation of Determination (r^2)

# %%
r = corr_matrix[..., ...]
r_squared = ...

print('r: ', r)
print('r_squared: ', r_squared)
# Out:
# r:  0.413518212472
# r_squared:  0.170997312046

# %% [markdown]
# **Question 3.1:** Create 2 variables to hold the mean of x and the mean of y

# %%
mean_x = np.mean(...)
mean_y = np.mean(...)

print('mean_x: ', mean_x)
print('mean_y: ', mean_y)
# Out:
# mean_x:  83.75
# mean_y:  74.1675

# %% [markdown]
# **Question 3.2:** Create 2 variables to hold the _standard deviation_ of x and the mean of y

# %%
std_x = np.std(...)
std_y = np.std(...)

print('std_x: ', std_x)
print('std_y: ', std_y)
# Out:
# std_x:  18.8331489666
# std_y:  17.7311450913

# %% [markdown]
# **Question 3.3:** Put it together: calculate the slope (b1) and intercept (b0)

# %%
b1 = ... * (... / ...)
b0 = ... - b1 * ...

print(f"Slope: {b1}")
print(f"Intercept: {b0}")
print(f"Regression Equation: ŷ = {b0} + {b1}x")
# Out:
# Slope: 0.38932158590308363
# Intercept: 41.56181718061675
# Regression Equation: ŷ = 41.56181718061675 + 0.38932158590308363x

# %% [markdown]
# <font color="brown" size="5">4. Plot the Regression Line 📈</font>

# %% [markdown]
# **Question 4.0** Recall that we're using quiz scores to predict course grades. Therefore, we'll treat `quiz_scores` as "x" on our plot. Fill in the following blanks:

# %%
# Create a range of x-values for the regression plot
x_values = np.arange(np.min(...), np.max(...) + 1)

# %% [markdown]
# **Question 4.1** Using b0 and b1 (the variables you defined earlier), and the provided x_values, fill in the blanks so that y_values follows the regression formula.

# %%
y_values = ... + ... * x_values

# %% [markdown]
# **Question 4.2** Fill in the blanks: `x_values` goes first, `y_values` second.

# %%
# TODO: Fill in the blanks here!
plt.plot(..., ..., color='red', label='Regression Line')

# ---DON'T CHANGE THE CODE BELOW---

# Add labels, a title, and a legend
plt.title('Regression: Quiz Score vs. Course Grade')
plt.xlabel('Quiz Score')
plt.ylabel('Course Grade')
plt.legend()

# Display the final plot with both elements
plt.scatter(quiz_scores, course_grades, label='Original Data')
plt.show()

# %% [markdown]
# Notice the scattered data points in blue, and the regression line in red. Think to yourself: does the regression line seem like a good fit for the data?

# %% [markdown]
# <font color="brown" size="5">5. Test your knowledge 🔎</font>

# %% [markdown]
# Don't forget to use the values you calculated above!

# %% [markdown]
# **Question 5.1** Report the correlation as seen in research articles. (when reporting p-value always say what it equals, but if p is less than .001 then report it as p < .001)
#
# **Answer:**  ...
#
# <br>
#
# **Question 5.2** Determine the strength and direction of the relationship. Hint: is it positive or negative? Is it weak, moderate, or strong?
#
# **Answer:** ...
#
# <br>
#
# **Question 5.3** Is the correlation significant or not?
#
# **Answer:** significant
#
# <br>
#
# **Question 5.4** What can you conclude about quiz scores and overall grade, based on the regression output?
#
# **Answer:** A student's quiz score is a statistically significant predictor of their course grade
#
# <br>

# %% [markdown]
# **Question 5.5** If a student has an overall quiz score of 85, what is their predicted course grade?

# %%
predicted_grade = ... + ... * 85

print(f'predicted grade: {predicted_grade}')
# Out:
# predicted grade: 74.65415198237886
